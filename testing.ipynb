# %%
import os
from utils import process_video, get_duration, process_video_segments

# %%
filename = "video.mp4"
get_duration(filename)
# Out:
# Duration: 104.85 seconds

# %%
start_time = 1
end_time = 104
sliding_window_size = 5

# %%
process_video()

# %%
os.makedirs("output_segments", exist_ok=True)
for current_start in range(start_time, end_time, sliding_window_size):
    window_size = current_start + sliding_window_size
    if window_size > end_time:
        window_size = end_time
    print(f"Processing from {current_start} to {window_size}")
    process_video(
        input_path="video.mp4",
        start_sec=current_start,
        end_sec=window_size,
        output_video_path=f"output_segments/video_{current_start}_{window_size}.mp4",
        output_audio_path=f"output_segments/audio_{current_start}_{window_size}.mp3"
    )
# Out:
# Processing from 1 to 6
# Loading video: video.mp4
# Saving sliced video to: output_segments/video_1_6.mp4
# MoviePy - Building video output_segments/video_1_6.mp4.
# MoviePy - Writing audio in video_1_6TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video output_segments/video_1_6.mp4
# MoviePy - Done !
# MoviePy - video ready output_segments/video_1_6.mp4
# Extracting audio to: output_segments/audio_1_6.mp3
# MoviePy - Writing audio in output_segments/audio_1_6.mp3
# MoviePy - Done.
# Done!
# Processing from 6 to 11
# Loading video: video.mp4
# Saving sliced video to: output_segments/video_6_11.mp4
# MoviePy - Building video output_segments/video_6_11.mp4.
# MoviePy - Writing audio in video_6_11TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video output_segments/video_6_11.mp4
# MoviePy - Done !
# MoviePy - video ready output_segments/video_6_11.mp4
# Extracting audio to: output_segments/audio_6_11.mp3
# ...

# %%
    sliced_video_name = "output_sliced.mp4"
    extracted_audio_name = "output_audio.mp3"

    # Time in seconds
    start_time = 10 
    end_time = 20

    process_video(input_file, sliced_video_name, extracted_audio_name, start_time, end_time)
